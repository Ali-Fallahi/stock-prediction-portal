# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

# %% [markdown]
# # Type of plots

# %% [markdown]
# ## Line plots

# %%
x = [1, 2, 3, 4, 5]
y = [10, 20, 25, 30, 40]

# %%
plt.plot(x,y);
plt.title("Simple Line Plot");
plt.xlabel("X-axis label");
plt.ylabel("Y-axis label");
plt.grid(True);

# %% [markdown]
# ## Bar Chart

# %%
months = ['Jan','Feb','Mar','Apr']
revenue = [100,200,300,500]

# %%
plt.figure(figsize=(10,6))
plt.bar(months, revenue)
plt.title("Monthly Revenue Bar Chart");
plt.xlabel("Months");
plt.ylabel("Revenue");

# %% [markdown]
# ## Histogram

# %%
marks50 = np.random.randint(0,100,50)
marks50
# Out:
# array([23, 85, 85, 72, 31, 28, 13, 27, 64,  2, 57, 33, 46, 88, 30, 94, 29,
#        19, 68,  2, 84, 91, 97,  9, 88, 25, 24, 13, 37, 14, 61, 91, 53, 14,
#        74,  5, 50, 37, 56, 78, 22, 19, 96,  8, 66, 52, 33, 27, 91, 31],
#       dtype=int32)

# %%
plt.hist(marks50);
plt.xlabel('Marks');
plt.ylabel('No. of students');

# %%
plt.hist(marks50, bins=5)
# Out:
# (array([11., 15.,  6.,  6., 12.]),
#  array([ 2., 21., 40., 59., 78., 97.]),
#  <BarContainer object of 5 artists>)

# %% [markdown]
# ## Scatter plot

# %%
heights = [65,70,68,72,66]
weights = [150,160,155,180,145]

# %%
plt.scatter(heights,weights)
plt.title('Heights vs. Weights Sctter Plot')
plt.xlabel('Height (inches)')
plt.ylabel('Weight (pounds)')
# Out:
# Text(0, 0.5, 'Weight (pounds)')

# %% [markdown]
# ## Subplots and Legends

# %%
days = [1,2,3,4,5]
original_price = [10,20,25,30,40]
predicted_price = [8, 21, 25, 28, 38]

# %%
plt.plot(days, original_price, 'b-o',label='Original Price')
plt.plot(days, predicted_price, 'r-o', label='Predicted Price')
plt.legend()
plt.title('Plot with legends')
plt.xlabel('Weekdays')
plt.ylabel('Price')
# Out:
# Text(0, 0.5, 'Price')

# %% [markdown]
# ## Subplots

# %%
# First subplot - Original Price
plt.subplot(3,1,1)
plt.plot(days, original_price, 'b-o',label='Original Price')
plt.title('Original prices over time')
plt.xlabel('Weekdays')
plt.ylabel('Price')
plt.legend()

# Second subplot - Predicted price
plt.subplot(3,1,2)
plt.plot(days, predicted_price, 'r-o', label='Predicted Price')
plt.title('Original prices over time')
plt.xlabel('Weekdays')
plt.ylabel('Price')
plt.legend()

# Third subplot - Difference between original and Predicted prices
price_difference = [o - p for o,p in zip(original_price, predicted_price)]
plt.subplot(3,1,3)
plt.bar(days, price_difference, color='purple', label='Price Difference')
plt.title('Difference between original and Predicted prices')
plt.xlabel('Days')
plt.ylabel('Price Difference')
plt.legend()

# %% [markdown]
# ##  Saving the figure

# %%
plt.plot(days, original_price, 'b-o',label='Original Price')
plt.plot(days, predicted_price, 'r-o', label='Predicted Price')
plt.legend()
plt.title('Plot with legends')
plt.xlabel('Weekdays')
plt.ylabel('Price')
plt.savefig('example_prediction.png', dpi=300)
